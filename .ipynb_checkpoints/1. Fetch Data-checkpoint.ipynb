# %% [markdown]
# # Fetch Google Location History Data

# %% [markdown]
# #### Head to Google Takeout:  https://takeout.google.com/settings/takeout)

# %% [markdown]
# #### 1. Click the Button "Select none"

# %%
from IPython.display import Image
Image(filename='images/download-data.png')

# %% [markdown]
# #### 2. Scroll Down and Select Location History
#
# #### 3. Ensure the JSON format is selected
#
# #### 4. Then click on "Next" to proceed

# %%
from IPython.display import Image
Image(filename='images/select-location-history-json.png')

# %% [markdown]
# #### 5. Now select the following options:
# * File type: .zip
# * Archive size (max): 2GB
# * Delivery Method: Send download link via email
#
# #### 6. Click 'Create archive'

# %%
from IPython.display import Image
Image(filename='images/create-archive.png')

# %% [markdown]
# ##### 7. Your location history data is now being prepared. This should take too long.

# %%
from IPython.display import Image
Image(filename='images/almost-there.png')

# %% [markdown]
# #### 8. Once the archive is ready, the option to Download will present itself under the detail header.
#
# #### 9. Download your data archive, remember where you save it to and then head over to the next notebook in this series to learn how to prepare the data to get it into a ESRI Point Shapefile for spatial analysis.

# %%
from IPython.display import Image
Image(filename='images/download-compressed-data.png')
